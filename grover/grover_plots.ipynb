# %%
import pandas

# %%
times = pandas.read_csv(open("grover_jsons/times.csv"))

# %%
import matplotlib.pyplot as plt

# %%
times
# Out:
#    qubit_num  ls_instruction_count  slices_count  slicing_time_s  total_time_s
# 0          3                   254           182        0.838098      0.844318
# 1          5                  2450          1902       10.056200     10.074852
# 2          6                  6900          5991       32.040100     32.089329
# 3          7                 18462         16179       87.417800     87.424718
# 4          8                 55384         48843      272.513000    272.528226
# 5          9                156962        138825      757.577000    757.581828
# 6         10                461320        408953        0.000000   2299.200000

# %%
fig, ax = plt.subplots(1,1, figsize=(16,9))
# ax2 = ax.twinx()
ax.plot(times["ls_instruction_count"], times["total_time_s"], '--o', ms= 2,lw=1, label="Slicing time")
ax.plot(times["ls_instruction_count"], times["slices_count"], '--*', label="Slice Count")
ax.legend(loc="lower left")
# ax2.plot(times["qubit_num"], times["slices_count"], '--.', label="Slices count")
ax.set_xlabel("Num of qubits in Grover's")
ax.set_ylabel("Time taken (s)")
# ax2.set_ylabel("Instruction/Slice counts")
plt.legend()
